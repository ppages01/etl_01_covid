# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import psycopg2 as engine
#load_dotenv()

# %% [markdown]
# # Dataset: Diversity of United States Counties (GENERAL DATA)
#
# Content: Diversity Index of Every US County using the Simpson Diversity Index: D = 1 - ∑(n/N)^2 (where n = number of people of a given race and N is the total number of people of all races, to get the probability of randomly selecting two people and getting two people of different races (ecological entropy))

# %% [markdown]
# # Dataset:  Covid 19 Infection / Death Data Set (US COUNTIES)
# The file contains the cumulative count of confirmed, death and recovered cases of COVID-19 from different countries from 22nd January 2020 to April 9 2020.

# %% [markdown]
# # FOCUS: FLORIDA COUNTIES

# %% [markdown]
# ### Extract CSVs into DataFrames

# %%
county_death = pd.read_csv("Resources/usa_county_wise.csv")
df1 = county_death.copy()
df1.head()
# Out:
#    UID iso2 iso3  code3  FIPS Admin2            Province_State Country_Region  \
# 0   16   AS  ASM     16  60.0    NaN            American Samoa             US
# 1  316   GU  GUM    316  66.0    NaN                      Guam             US
# 2  580   MP  MNP    580  69.0    NaN  Northern Mariana Islands             US
# 3  630   PR  PRI    630  72.0    NaN               Puerto Rico             US
# 4  850   VI  VIR    850  78.0    NaN            Virgin Islands             US
#
#        Lat     Long_                  Combined_Key     Date  Confirmed  Deaths
# 0 -14.2710 -170.1320            American Samoa, US  1/22/20          0       0
# 1  13.4443  144.7937                      Guam, US  1/22/20          0       0
# 2  15.0979  145.6739  Northern Mariana Islands, US  1/22/20          0       0
# 3  18.2208  -66.5901               Puerto Rico, US  1/22/20          0       0
# 4  18.3358  -64.8963            Virgin Islands, US  1/22/20          0       0

# %% [markdown]
# ### Extract XLSX into DataFrames

# %%
#reading new dataset
diversity = pd.read_excel("Resources/diversityindex.xlsx")
df2 = diversity.copy()
df2.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9

# %% [markdown]
# # Transform Dataset 1

# %%
#drop irrevelant columns
df1 = df1.drop(['Lat', 'Long_', 'UID', 'iso2', 'iso3','code3','FIPS','Admin2'], axis=1)

# %%
df1
# Out:
#                   Province_State Country_Region                  Combined_Key  \
# 0                 American Samoa             US            American Samoa, US
# 1                           Guam             US                      Guam, US
# 2       Northern Mariana Islands             US  Northern Mariana Islands, US
# 3                    Puerto Rico             US               Puerto Rico, US
# 4                 Virgin Islands             US            Virgin Islands, US
# ...                          ...            ...                           ...
# 293485                      Utah             US        Central Utah, Utah, US
# 293486                      Utah             US      Southeast Utah, Utah, US
# 293487                      Utah             US      Southwest Utah, Utah, US
# 293488                      Utah             US           TriCounty, Utah, US
# 293489                      Utah             US        Weber-Morgan, Utah, US
#
#            Date  Confirmed  Deaths
# 0       1/22/20          0       0
# 1       1/22/20          0       0
# 2       1/22/20          0       0
# 3       1/22/20          0       0
# 4       1/22/20          0       0
# ...         ...        ...     ...
# 293485  4/20/20         17       0
# 293486  4/20/20          7       0
# 293487  4/20/20         70       1
# 293488  4/20/20         10       0
# 293489  4/20/20        124       1
#
# [293490 rows x 6 columns]

# %%
#split Combined_Key column to seperate county name into it's own column
split = df1["Combined_Key"].str.split(",", n = 2, expand = True)

# %%
#reviewing the split process
split
# Out:
#                                0      1     2
# 0                 American Samoa     US  None
# 1                           Guam     US  None
# 2       Northern Mariana Islands     US  None
# 3                    Puerto Rico     US  None
# 4                 Virgin Islands     US  None
# ...                          ...    ...   ...
# 293485              Central Utah   Utah    US
# 293486            Southeast Utah   Utah    US
# 293487            Southwest Utah   Utah    US
# 293488                 TriCounty   Utah    US
# 293489              Weber-Morgan   Utah    US
#
# [293490 rows x 3 columns]

# %%
#adding the new column to the dataframe
df1['County'] = split[0]

# %%
df1
# Out:
#                   Province_State Country_Region                  Combined_Key  \
# 0                 American Samoa             US            American Samoa, US
# 1                           Guam             US                      Guam, US
# 2       Northern Mariana Islands             US  Northern Mariana Islands, US
# 3                    Puerto Rico             US               Puerto Rico, US
# 4                 Virgin Islands             US            Virgin Islands, US
# ...                          ...            ...                           ...
# 293485                      Utah             US        Central Utah, Utah, US
# 293486                      Utah             US      Southeast Utah, Utah, US
# 293487                      Utah             US      Southwest Utah, Utah, US
# 293488                      Utah             US           TriCounty, Utah, US
# 293489                      Utah             US        Weber-Morgan, Utah, US
#
#            Date  Confirmed  Deaths                    County
# 0       1/22/20          0       0            American Samoa
# 1       1/22/20          0       0                      Guam
# 2       1/22/20          0       0  Northern Mariana Islands
# 3       1/22/20          0       0               Puerto Rico
# 4       1/22/20          0       0            Virgin Islands
# ...         ...        ...     ...                       ...
# 293485  4/20/20         17       0              Central Utah
# 293486  4/20/20          7       0            Southeast Utah
# 293487  4/20/20         70       1            Southwest Utah
# 293488  4/20/20         10       0                 TriCounty
# 293489  4/20/20        124       1              Weber-Morgan
#
# [293490 rows x 7 columns]

# %%
#drop Combined_Key column
df1 = df1.drop(['Combined_Key'], axis=1)

# %%
#focus on Florida
df1_florida = df1[df1['Province_State'] == 'Florida']
df1_florida
# Out:
#        Province_State Country_Region     Date  Confirmed  Deaths      County
# 325           Florida             US  1/22/20          0       0     Alachua
# 326           Florida             US  1/22/20          0       0       Baker
# 327           Florida             US  1/22/20          0       0         Bay
# 328           Florida             US  1/22/20          0       0    Bradford
# 329           Florida             US  1/22/20          0       0     Brevard
# ...               ...            ...      ...        ...     ...         ...
# 290618        Florida             US  4/20/20         15       1     Wakulla
# 290619        Florida             US  4/20/20         32       0      Walton
# 290620        Florida             US  4/20/20          6       0  Washington
# 293387        Florida             US  4/20/20          0       0   Out of FL
# 293439        Florida             US  4/20/20          3       0  Unassigned
#
# [6210 rows x 6 columns]

# %%
#group by county 
df_bycounty = df1_florida.groupby(['County']).agg('max')

# %%
df_bycounty
# Out:
#            Province_State Country_Region    Date  Confirmed  Deaths
# County
# Alachua           Florida             US  4/9/20        218       0
# Baker             Florida             US  4/9/20         17       3
# Bay               Florida             US  4/9/20         57       2
# Bradford          Florida             US  4/9/20         42       2
# Brevard           Florida             US  4/9/20        218       7
# ...                   ...            ...     ...        ...     ...
# Union             Florida             US  4/9/20          3       0
# Volusia           Florida             US  4/9/20        342      10
# Wakulla           Florida             US  4/9/20         15       2
# Walton            Florida             US  4/9/20         32       0
# Washington        Florida             US  4/9/20          6       0
#
# [69 rows x 5 columns]

# %%
df1 = df_bycounty.copy()

# %% [markdown]
# # Transform Dataset 2

# %%
#second dataset, general diversity stats 2013

# %%
df2.head()
# Out:
#                          Location  Diversity-Index  \
# 0  Aleutians West Census Area, AK         0.769346
# 1               Queens County, NY         0.742224
# 2                 Maui County, HI         0.740757
# 3              Alameda County, CA         0.740399
# 4      Aleutians East Borough, AK         0.738867
#
#    Black or African American alone, percent, 2013  \
# 0                                             7.4
# 1                                            20.9
# 2                                             0.8
# 3                                            12.4
# 4                                             7.7
#
#    American Indian and Alaska Native alone, percent, 2013  \
# 0                                               13.8
# 1                                                1.3
# 2                                                0.6
# 3                                                1.2
# 4                                               21.8
#
#    Asian alone, percent, 2013  \
# 0                        31.1
# 1                        25.2
# 2                        28.8
# 3                        28.2
# 4                        41.4
#
#    Native Hawaiian and Other Pacific Islander alone, percent,  \
# 0                                                2.3
# 1                                                0.2
# 2                                               10.6
# 3                                                1.0
# 4                                                0.7
#
#    Two or More Races, percent, 2013  Hispanic or Latino, percent, 2013  \
# 0                               4.8                               14.6
# 1                               2.7                               28.0
# 2                              23.3                               10.7
# 3                               5.2                               22.7
# 4                               3.7                               13.5
#
#    White alone, not Hispanic or Latino, percent, 2013
# 0                                               29.2
# 1                                               26.7
# 2                                               31.5
# 3                                               33.2
# 4                                               12.9

# %%
#column rename
df2 = df2.rename(columns=\
                            {'Black or African American alone, percent, 2013':'Black',\
                             'American Indian and Alaska Native alone, percent, 2013': 'Native American',\
                             'Asian alone, percent, 2013' : 'Asian',\
                             'Native Hawaiian and Other Pacific Islander alone, percent,' : 'Pacific Islander',\
                             'Two or More Races, percent, 2013' : 'Plus two races',\
                             'Hispanic or Latino, percent, 2013' : 'Hispanic',\
                             'White alone, not Hispanic or Latino, percent, 2013' : 'White'})

# %%
#split location into county and state

# %%
split2 = df2["Location"].str.split(",", n = 1, expand = True)

# %%
split2
# Out:
#                                0    1
# 0     Aleutians West Census Area   AK
# 1                  Queens County   NY
# 2                    Maui County   HI
# 3                 Alameda County   CA
# 4         Aleutians East Borough   AK
# ...                          ...  ...
# 3190                Osage County   MO
# 3191              Lincoln County   WV
# 3192               Leslie County   KY
# 3193               Blaine County   NE
# 3194            Keya Paha County   NE
#
# [3195 rows x 2 columns]

# %%
#adding the new columns

# %%
df2['County']=split2[0]

# %%
df2['State']=split2[1]

# %%
df2
# Out:
#                             Location  Diversity-Index  Black  Native American  \
# 0     Aleutians West Census Area, AK         0.769346    7.4             13.8
# 1                  Queens County, NY         0.742224   20.9              1.3
# 2                    Maui County, HI         0.740757    0.8              0.6
# 3                 Alameda County, CA         0.740399   12.4              1.2
# 4         Aleutians East Borough, AK         0.738867    7.7             21.8
# ...                              ...              ...    ...              ...
# 3190                Osage County, MO         0.037540    0.3              0.2
# 3191              Lincoln County, WV         0.035585    0.2              0.1
# 3192               Leslie County, KY         0.035581    0.4              0.1
# 3193               Blaine County, NE         0.023784    0.2              0.0
# 3194            Keya Paha County, NE         0.021816    0.0              0.1
#
#       Asian  Pacific Islander  Plus two races  Hispanic  White  \
# 0      31.1               2.3             4.8      14.6   29.2
# 1      25.2               0.2             2.7      28.0   26.7
# 2      28.8              10.6            23.3      10.7   31.5
# 3      28.2               1.0             5.2      22.7   33.2
# 4      41.4               0.7             3.7      13.5   12.9
# ...     ...               ...             ...       ...    ...
# 3190    0.1               0.0             0.7       0.6   98.1
# 3191    0.1               0.0             0.7       0.6   98.2
# 3192    0.2               0.0             0.7       0.5   98.2
# 3193    0.0               0.0             0.8       0.2   98.8
# 3194    0.1               0.0             0.6       0.5   98.9
#
#                           County State
# 0     Aleutians West Census Area    AK
# 1                  Queens County    NY
# 2                    Maui County    HI
# 3                 Alameda County    CA
# 4         Aleutians East Borough    AK
# ...                          ...   ...
# 3190                Osage County    MO
# 3191              Lincoln County    WV
# 3192               Leslie County    KY
# 3193               Blaine County    NE
# 3194            Keya Paha County    NE
#
# [3195 rows x 11 columns]

# %%
# FOCUS on florida and remove  leading spacing in column name
diversity_FL = df2[df2['State'] == ' FL'].copy()

# %%
diversity_FL['State'] = diversity_FL['State'].str.lstrip()

# %%
df2 = diversity_FL.copy()

# %%
df2
# Out:
#                      Location  Diversity-Index  Black  Native American  Asian  \
# 31         Broward County, FL         0.678237   28.5              0.4    3.6
# 34          Orange County, FL         0.671218   22.0              0.6    5.4
# 71    Hillsborough County, FL         0.626423   17.4              0.5    3.9
# 96          Hendry County, FL         0.609280   13.4              2.2    1.1
# 103        Osceola County, FL         0.605921   13.1              0.8    3.0
# ...                       ...              ...    ...              ...    ...
# 1663         Dixie County, FL         0.257861    8.9              0.4    0.4
# 1779        Holmes County, FL         0.234000    6.6              0.9    0.7
# 1782        Nassau County, FL         0.233596    6.5              0.5    1.0
# 1791     Gilchrist County, FL         0.231825    5.6              0.6    0.5
# 1926        Citrus County, FL         0.204041    3.1              0.4    1.6
#
#       Pacific Islander  Plus two races  Hispanic  White               County  \
# 31                 0.1             2.0      26.9   40.8       Broward County
# 34                 0.2             2.4      28.7   44.1        Orange County
# 71                 0.1             2.5      26.0   52.3  Hillsborough County
# 96                 0.2             1.1      50.3   34.5        Hendry County
# 103                0.2             2.5      48.6   37.3       Osceola County
# ...                ...             ...       ...    ...                  ...
# 1663               0.0             1.5       3.5   85.6         Dixie County
# 1779               0.1             2.0       2.7   87.2        Holmes County
# 1782               0.1             1.5       3.8   87.2        Nassau County
# 1791               0.1             1.2       5.2   87.3     Gilchrist County
# 1926               0.0             1.5       4.9   89.0        Citrus County
#
#      State
# 31      FL
# 34      FL
# 71      FL
# 96      FL
# 103     FL
# ...    ...
# 1663    FL
# 1779    FL
# 1782    FL
# 1791    FL
# 1926    FL
#
# [67 rows x 11 columns]

# %%
#test to make sure leading space is gone
df2[df2['State'] == 'FL']
# Out:
#                      Location  Diversity-Index  Black  Native American  Asian  \
# 31         Broward County, FL         0.678237   28.5              0.4    3.6
# 34          Orange County, FL         0.671218   22.0              0.6    5.4
# 71    Hillsborough County, FL         0.626423   17.4              0.5    3.9
# 96          Hendry County, FL         0.609280   13.4              2.2    1.1
# 103        Osceola County, FL         0.605921   13.1              0.8    3.0
# ...                       ...              ...    ...              ...    ...
# 1663         Dixie County, FL         0.257861    8.9              0.4    0.4
# 1779        Holmes County, FL         0.234000    6.6              0.9    0.7
# 1782        Nassau County, FL         0.233596    6.5              0.5    1.0
# 1791     Gilchrist County, FL         0.231825    5.6              0.6    0.5
# 1926        Citrus County, FL         0.204041    3.1              0.4    1.6
#
#       Pacific Islander  Plus two races  Hispanic  White               County  \
# 31                 0.1             2.0      26.9   40.8       Broward County
# 34                 0.2             2.4      28.7   44.1        Orange County
# 71                 0.1             2.5      26.0   52.3  Hillsborough County
# 96                 0.2             1.1      50.3   34.5        Hendry County
# 103                0.2             2.5      48.6   37.3       Osceola County
# ...                ...             ...       ...    ...                  ...
# 1663               0.0             1.5       3.5   85.6         Dixie County
# 1779               0.1             2.0       2.7   87.2        Holmes County
# 1782               0.1             1.5       3.8   87.2        Nassau County
# 1791               0.1             1.2       5.2   87.3     Gilchrist County
# 1926               0.0             1.5       4.9   89.0        Citrus County
#
#      State
# 31      FL
# 34      FL
# 71      FL
# 96      FL
# 103     FL
# ...    ...
# 1663    FL
# 1779    FL
# 1782    FL
# 1791    FL
# 1926    FL
#
# [67 rows x 11 columns]

# %%
#remove the word 'County' from county column, so we can merge tables.
df2['County'] = df2['County'].str.replace(r'County', '')

# %%
df2
# Out:
#                      Location  Diversity-Index  Black  Native American  Asian  \
# 31         Broward County, FL         0.678237   28.5              0.4    3.6
# 34          Orange County, FL         0.671218   22.0              0.6    5.4
# 71    Hillsborough County, FL         0.626423   17.4              0.5    3.9
# 96          Hendry County, FL         0.609280   13.4              2.2    1.1
# 103        Osceola County, FL         0.605921   13.1              0.8    3.0
# ...                       ...              ...    ...              ...    ...
# 1663         Dixie County, FL         0.257861    8.9              0.4    0.4
# 1779        Holmes County, FL         0.234000    6.6              0.9    0.7
# 1782        Nassau County, FL         0.233596    6.5              0.5    1.0
# 1791     Gilchrist County, FL         0.231825    5.6              0.6    0.5
# 1926        Citrus County, FL         0.204041    3.1              0.4    1.6
#
#       Pacific Islander  Plus two races  Hispanic  White         County State
# 31                 0.1             2.0      26.9   40.8       Broward     FL
# 34                 0.2             2.4      28.7   44.1        Orange     FL
# 71                 0.1             2.5      26.0   52.3  Hillsborough     FL
# 96                 0.2             1.1      50.3   34.5        Hendry     FL
# 103                0.2             2.5      48.6   37.3       Osceola     FL
# ...                ...             ...       ...    ...            ...   ...
# 1663               0.0             1.5       3.5   85.6         Dixie     FL
# 1779               0.1             2.0       2.7   87.2        Holmes     FL
# 1782               0.1             1.5       3.8   87.2        Nassau     FL
# 1791               0.1             1.2       5.2   87.3     Gilchrist     FL
# 1926               0.0             1.5       4.9   89.0        Citrus     FL
#
# [67 rows x 11 columns]

# %%
#remove extra space following county name
df2['County'] = df2['County'].str.rstrip()

# %%
df2[df2['County'] == 'Broward']
# Out:
#               Location  Diversity-Index  Black  Native American  Asian  \
# 31  Broward County, FL         0.678237   28.5              0.4    3.6
#
#     Pacific Islander  Plus two races  Hispanic  White   County State
# 31               0.1             2.0      26.9   40.8  Broward    FL

# %% [markdown]
# # MERGE THE DATASETS

# %%
#perform the merge

# %%
merged = pd.merge(df1,df2, on='County', how='outer')

# %%
merged
# Out:
#         County Province_State Country_Region    Date  Confirmed  Deaths  \
# 0      Alachua        Florida             US  4/9/20        218       0
# 1        Baker        Florida             US  4/9/20         17       3
# 2          Bay        Florida             US  4/9/20         57       2
# 3     Bradford        Florida             US  4/9/20         42       2
# 4      Brevard        Florida             US  4/9/20        218       7
# ..         ...            ...            ...     ...        ...     ...
# 64       Union        Florida             US  4/9/20          3       0
# 65     Volusia        Florida             US  4/9/20        342      10
# 66     Wakulla        Florida             US  4/9/20         15       2
# 67      Walton        Florida             US  4/9/20         32       0
# 68  Washington        Florida             US  4/9/20          6       0
#
#                  Location  Diversity-Index  Black  Native American  Asian  \
# 0      Alachua County, FL         0.547155   20.4              0.3    5.7
# 1        Baker County, FL         0.307153   13.4              0.4    0.7
# 2          Bay County, FL         0.371522   11.2              0.8    2.3
# 3     Bradford County, FL         0.398624   19.3              0.4    0.5
# 4      Brevard County, FL         0.395788   10.6              0.5    2.3
# ..                    ...              ...    ...              ...    ...
# 64       Union County, FL         0.446389   22.5              0.4    0.3
# 65     Volusia County, FL         0.420775   11.0              0.5    1.7
# 66     Wakulla County, FL         0.354523   15.1              0.7    0.5
# 67      Walton County, FL         0.284614    5.9              1.0    1.0
# 68  Washington County, FL         0.373520   15.5              1.4    0.6
#
#     Pacific Islander  Plus two races  Hispanic  White State
# 0                0.1             2.5       8.9   63.2    FL
# 1                0.0             1.6       2.3   82.1    FL
# 2                0.1             3.0       5.4   78.2    FL
# 3                0.1             1.7       3.6   75.0    FL
# 4                0.1             2.5       9.0   76.4    FL
# ..               ...             ...       ...    ...   ...
# 64               0.0             1.4       5.4   70.7    FL
# 65               0.1             1.9      12.0   74.3    FL
# 66               0.1             1.9       3.6   78.8    FL
# 67               0.2             2.4       6.2   84.1    FL
# 68               0.1             2.1       3.4   77.5    FL
#
# [69 rows x 16 columns]

# %%
# rename a column and drop 'location columns'

# %%
merged = merged.rename(columns = {'Confirmed' : 'Confirmed Cases'})

# %%
merged = merged.drop('Location', axis=1)

# %%
#end result
merged
# Out:
#         County Province_State Country_Region    Date  Confirmed Cases  Deaths  \
# 0      Alachua        Florida             US  4/9/20              218       0
# 1        Baker        Florida             US  4/9/20               17       3
# 2          Bay        Florida             US  4/9/20               57       2
# 3     Bradford        Florida             US  4/9/20               42       2
# 4      Brevard        Florida             US  4/9/20              218       7
# ..         ...            ...            ...     ...              ...     ...
# 64       Union        Florida             US  4/9/20                3       0
# 65     Volusia        Florida             US  4/9/20              342      10
# 66     Wakulla        Florida             US  4/9/20               15       2
# 67      Walton        Florida             US  4/9/20               32       0
# 68  Washington        Florida             US  4/9/20                6       0
#
#     Diversity-Index  Black  Native American  Asian  Pacific Islander  \
# 0          0.547155   20.4              0.3    5.7               0.1
# 1          0.307153   13.4              0.4    0.7               0.0
# 2          0.371522   11.2              0.8    2.3               0.1
# 3          0.398624   19.3              0.4    0.5               0.1
# 4          0.395788   10.6              0.5    2.3               0.1
# ..              ...    ...              ...    ...               ...
# 64         0.446389   22.5              0.4    0.3               0.0
# 65         0.420775   11.0              0.5    1.7               0.1
# 66         0.354523   15.1              0.7    0.5               0.1
# 67         0.284614    5.9              1.0    1.0               0.2
# 68         0.373520   15.5              1.4    0.6               0.1
#
#     Plus two races  Hispanic  White State
# 0              2.5       8.9   63.2    FL
# 1              1.6       2.3   82.1    FL
# 2              3.0       5.4   78.2    FL
# 3              1.7       3.6   75.0    FL
# 4              2.5       9.0   76.4    FL
# ..             ...       ...    ...   ...
# 64             1.4       5.4   70.7    FL
# 65             1.9      12.0   74.3    FL
# 66             1.9       3.6   78.8    FL
# 67             2.4       6.2   84.1    FL
# 68             2.1       3.4   77.5    FL
#
# [69 rows x 15 columns]

# %%
#final rename for loading to database
merged = merged.rename(columns={'County':'county',\
                                'Confirmed Cases' : 'confirmedcases',\
                                'Deaths' : 'deaths',\
                                'Diversity-Index' : 'diversityindex',\
                                'Black' : 'black',\
                                'Native American' : 'nativeamerican',\
                                'Asian' : 'asian',\
                                'Pacific Islander' : 'pacificislander',\
                                'Plus two races' : 'plustworaces',\
                                'Hispanic': 'hispanic',\
                                'White' : 'white',\
                                'State': 'state'})

# %%
merged.head()
# Out:
#      county Province_State Country_Region    Date  confirmedcases  deaths  \
# 0   Alachua        Florida             US  4/9/20             218       0
# 1     Baker        Florida             US  4/9/20              17       3
# 2       Bay        Florida             US  4/9/20              57       2
# 3  Bradford        Florida             US  4/9/20              42       2
# 4   Brevard        Florida             US  4/9/20             218       7
#
#    diversityindex  black  nativeamerican  asian  pacificislander  \
# 0        0.547155   20.4             0.3    5.7              0.1
# 1        0.307153   13.4             0.4    0.7              0.0
# 2        0.371522   11.2             0.8    2.3              0.1
# 3        0.398624   19.3             0.4    0.5              0.1
# 4        0.395788   10.6             0.5    2.3              0.1
#
#    plustworaces  hispanic  white state
# 0           2.5       8.9   63.2    FL
# 1           1.6       2.3   82.1    FL
# 2           3.0       5.4   78.2    FL
# 3           1.7       3.6   75.0    FL
# 4           2.5       9.0   76.4    FL

# %%
#drop the final unnecessary columns
merged = merged.drop(['Province_State', 'Country_Region','Date'], axis=1)

# %%
merged
# Out:
#         county  confirmedcases  deaths  diversityindex  black  nativeamerican  \
# 0      Alachua             218       0        0.547155   20.4             0.3
# 1        Baker              17       3        0.307153   13.4             0.4
# 2          Bay              57       2        0.371522   11.2             0.8
# 3     Bradford              42       2        0.398624   19.3             0.4
# 4      Brevard             218       7        0.395788   10.6             0.5
# ..         ...             ...     ...             ...    ...             ...
# 64       Union               3       0        0.446389   22.5             0.4
# 65     Volusia             342      10        0.420775   11.0             0.5
# 66     Wakulla              15       2        0.354523   15.1             0.7
# 67      Walton              32       0        0.284614    5.9             1.0
# 68  Washington               6       0        0.373520   15.5             1.4
#
#     asian  pacificislander  plustworaces  hispanic  white state
# 0     5.7              0.1           2.5       8.9   63.2    FL
# 1     0.7              0.0           1.6       2.3   82.1    FL
# 2     2.3              0.1           3.0       5.4   78.2    FL
# 3     0.5              0.1           1.7       3.6   75.0    FL
# 4     2.3              0.1           2.5       9.0   76.4    FL
# ..    ...              ...           ...       ...    ...   ...
# 64    0.3              0.0           1.4       5.4   70.7    FL
# 65    1.7              0.1           1.9      12.0   74.3    FL
# 66    0.5              0.1           1.9       3.6   78.8    FL
# 67    1.0              0.2           2.4       6.2   84.1    FL
# 68    0.6              0.1           2.1       3.4   77.5    FL
#
# [69 rows x 12 columns]

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:Password123@localhost:5432/etl_project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['countycovid']

# %% [markdown]
# ### Load DataFrames into database

# %%
merged.to_sql(name='countycovid', con=engine, if_exists='append', index=False)
